# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os, sys
from obspy import read

# %%
file_names = list(filter(lambda f: os.path.splitext(f)[1] == '.mseed', os.listdir('data/miniseed/')))

# %%
print(file_names[-1])
print(file_names[-2])
print(file_names[-3])
stream = read(os.path.join('data/miniseed', file_names[-1]))
# stream += read(os.path.join('data/miniseed', file_names[-2]))
# stream += read(os.path.join('data/miniseed', file_names[-3]))
# Out:
# ELYSE_00_HHW_2019-03-09T11:14:41.687000Z.mseed
# ELYSE_00_HHU_2019-02-10T14:21:59.679000Z.mseed
# ELYSE_00_HHV_2019-02-23T00:44:34.121000Z.mseed

# %%
type(stream)
# Out:
# obspy.core.stream.Stream

# %%
stream.plot()
